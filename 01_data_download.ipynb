# %%
! pip install -q kaggle

# %%
! cd ~

# %%
! pwd
# Out:
# /content

# %%
 from google.colab import files
 files.upload()
# Out:
#      <input type="file" id="files-f209912f-2c45-48cf-b407-d8f3a87446d0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f209912f-2c45-48cf-b407-d8f3a87446d0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! mkdir ~/.kaggle

# %%
! ls -l ~/.kaggle
# Out:
# total 4
# -rw------- 1 root root 62 Sep 21 04:56 kaggle.json

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! ls -l /content/drive/MyDrive/as/biotec/kaggle/scp/input
# Out:
# total 0

# %%
! kaggle datasets list -s 'Single-Cell Perturbations'
# Out:
# ref                                                             title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# alexandervc/scrnaseq-crisprperturbseqnormanselectedpart         scRNA-seq +CRISPR=Perturb-seq.Norman.SelectedPart  151MB  2022-07-20 11:54:23             20          3  0.625
# saurabhshahane/phenotypic-plasticity-of-the-actin-cytoskeleton  Phenotypic plasticity of the actin cytoskeleton    522MB  2021-03-26 07:43:42             30          9  0.7647059

# %%
! kaggle competitions download -c open-problems-single-cell-perturbations
# Out:
# ...
# 100% 3.80G/3.81G [00:45<00:00, 106MB/s]
# 100% 3.81G/3.81G [00:45<00:00, 89.2MB/s]

# %%
! ls -l /content
# Out:
# total 3999788
# -rw-r--r-- 1 root root         62 Sep 21 04:55 kaggle.json
# -rw-r--r-- 1 root root 4095766730 Sep 12 18:43 open-problems-single-cell-perturbations.zip
# drwxr-xr-x 1 root root       4096 Sep 19 13:44 sample_data

# %%
! ls -l /content
# Out:
# total 3999788
# -rw-r--r-- 1 root root         62 Sep 21 04:55 kaggle.json
# -rw-r--r-- 1 root root 4095766730 Sep 12 18:43 open-problems-single-cell-perturbations.zip
# drwxr-xr-x 1 root root       4096 Sep 19 13:44 sample_data

# %%
! mkdir input
# Out:
# mkdir: cannot create directory ‘single_cell_p’: File exists

# %%
! unzip /content/open-problems-single-cell-perturbations.zip -d  /content/drive/MyDrive/as/biotec/kaggle/scp/input
# Out:
# Archive:  /content/open-problems-single-cell-perturbations.zip
#   inflating: /content/drive/MyDrive/as/biotec/kaggle/scp/input/adata_obs_meta.csv
#   inflating: /content/drive/MyDrive/as/biotec/kaggle/scp/input/adata_train.parquet
#   inflating: /content/drive/MyDrive/as/biotec/kaggle/scp/input/de_train.parquet
#   inflating: /content/drive/MyDrive/as/biotec/kaggle/scp/input/id_map.csv
#   inflating: /content/drive/MyDrive/as/biotec/kaggle/scp/input/multiome_obs_meta.csv
#   inflating: /content/drive/MyDrive/as/biotec/kaggle/scp/input/multiome_train.parquet
#   inflating: /content/drive/MyDrive/as/biotec/kaggle/scp/input/multiome_var_meta.csv
#   inflating: /content/drive/MyDrive/as/biotec/kaggle/scp/input/sample_submission.csv

# %%
import numpy as np
import pandas as pd

# %%
train_path = '/content/drive/MyDrive/as/biotec/kaggle/scp/input/de_train.parquet'
df_train = pd.read_parquet(train_path)
print(df_train.shape)
df_train
# Out:
# (614, 18216)
#               cell_type             sm_name sm_lincs_id  \
# 0              NK cells        Clotrimazole    LSM-5341
# 1          T cells CD4+        Clotrimazole    LSM-5341
# 2          T cells CD8+        Clotrimazole    LSM-5341
# 3    T regulatory cells        Clotrimazole    LSM-5341
# 4              NK cells  Mometasone Furoate    LSM-3349
# ..                  ...                 ...         ...
# 609  T regulatory cells        Atorvastatin    LSM-5771
# 610            NK cells           Riociguat   LSM-45758
# 611        T cells CD4+           Riociguat   LSM-45758
# 612        T cells CD8+           Riociguat   LSM-45758
# 613  T regulatory cells           Riociguat   LSM-45758
#
#                                                 SMILES  control      A1BG  \
# 0               Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1    False  0.104720
# 1               Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1    False  0.915953
# ...
